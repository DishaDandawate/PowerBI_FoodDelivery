# %% [markdown]
# # Power BI Food Delivery Analysis
# This dataset and analysis were performed in Power BI.
# The exported CSV file is attached for reference.

# %%
import pandas as pd
df= pd.read_csv("final_food_delivery_dataset.csv")
df.head()
# Out:
#    order_id  user_id  restaurant_id order_date  total_amount  \
# 0      5865     2835            350  20-May-23        563.57
# 1       498     2119             12  02-Dec-23        989.29
# 2      1816       37             45  15-Sep-23       1209.30
# 3       148     1975             73  06-Feb-23        607.82
# 4       660       59            124  15-Sep-23       1251.48
#
#                     restaurant_name  users.user_id users.name users.city  \
# 0  Classic Curry House South Indian           2835  User_2835  Bangalore
# 1          Royal Foods Multicuisine           2119  User_2119  Bangalore
# 2      Annapurna Restaurant Punjabi             37    User_37  Bangalore
# 3                 Spice Mess Andhra           1975  User_1975  Bangalore
# 4                Spice Dhaba Andhra             59    User_59  Bangalore
#
#   users.membership  restaurants (3).restaurant_id  \
# 0             Gold                            350
# 1          Regular                             12
# ...
